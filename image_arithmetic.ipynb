# %% [markdown]
# # How an image is seen by computer

# %% [markdown]
# This notebook explains arithmetic on images. Explains methods for detecting interest points in images.

# %% [markdown]
# ### Import required packages

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %%
#TO DO add user friendly description of code logic. Guidelines to write is

# %%
#TO DO choose your own greyscale image 32X32
#file = "a-puppy.jpg"
file = "dolphin.png"
im = Image.open(file)
display(im)
print('Resolution', im.size)
print('mode', im.mode)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=500x320 at 0x10A0B3630>
# Resolution (500, 320)
# mode L

# %%
#TO DO take a 32X32 image and print its matrix values.

# %% [markdown]
# pixel means picture elements

# %%
#TO DO update row 0 and all columns of the above matrix to zero and display the image

# %%
pixels = im.load()
print(pixels[5,4])

pixels[4,4]=0
# using getpixel method 
print (im.getpixel((4, 4))) 
cordinate = x, y = 150, 59
print (im.getpixel(cordinate));
display(im)
# Out:
# <class 'PixelAccess'>
# 62
# 0
# 249
# <PIL.PngImagePlugin.PngImageFile image mode=L size=500x320 at 0x10A0B3630>

# %%
#TODO Add description of the below code logic here

# %%
def invert(pixel, num=0.5): 
    return pixel * num

processed_im = im.point(invert)
display(processed_im)
# Out:
# <PIL.Image.Image image mode=L size=500x320 at 0x10B041550>

# %%
#TO DO Invert ( means if the pixel value is 5, its inverted value = 255 - 5 = 250 ) pixel values and display the image
f(x) = 255 - x

# %%
#TODO
Gray image transforms: Applying functions.  
     a) clamping the image with f(x) = (100/255)x + 100
     b) quadratic transformation with f(x) = 255(x/255)^2
